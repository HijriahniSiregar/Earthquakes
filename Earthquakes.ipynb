# %% [markdown]
# 🌟 Introduction
# Hi! In this project, I explored global earthquake data from 1965 up to the present. My goal was to better understand how often earthquakes happen, how strong they are, where they usually occur, and how their depth relates to their magnitude.
#
# This notebook uses Python and several data visualization libraries like Seaborn and Plotly to analyze and visualize earthquake patterns. I cleaned the dataset, checked for missing values, looked at how magnitudes are distributed, and also mapped where earthquakes happen around the world.
#
# This project is part of my learning journey in data science, and I hope others can learn from it too or get inspired to dig deeper into geospatial data!
# **Dataset Source**
# This dataset was sourced from Kaggle:
# [Global Earthquake Dataset on Kaggle](https://www.kaggle.com/discussions/accomplishments/480456)

# %% [markdown]
# # 🌍 Global Earthquake Data Analysis (1965–Present)
#
# This project explores global earthquake data from 1965 to the present, offering insights into earthquake frequency, magnitude, depth, and geographic distribution.

# %%
# 📦 Import libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

sns.set(style="whitegrid")

# 📂 Load dataset
df = pd.read_csv("database.csv")
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
df['Year'] = df['Date'].dt.year
df.head()
# Out:
#         Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0 1965-01-02  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1 1965-01-04  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2 1965-01-05  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3 1965-01-08  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4 1965-01-09  13:32:50    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  Azimuthal Gap  \
# 0                     NaN        6.0             MW  ...            NaN
# 1                     NaN        5.8             MW  ...            NaN
# 2                     NaN        6.2             MW  ...            NaN
# 3                     NaN        5.8             MW  ...            NaN
# 4                     NaN        5.8             MW  ...            NaN
#
#    Horizontal Distance  Horizontal Error  Root Mean Square            ID  \
# ...

# %%
# 🧼 Check missing values
df.isnull().sum().sort_values(ascending=False)
# Out:
# Magnitude Error               23085
# Horizontal Error              22256
# Horizontal Distance           21808
# Magnitude Seismic Stations    20848
# Depth Error                   18951
# Depth Seismic Stations        16315
# Azimuthal Gap                 16113
# Root Mean Square               6060
# Magnitude Type                    3
# Date                              3
# Year                              3
# Magnitude                         0
# Time                              0
# Depth                             0
# Type                              0
# Longitude                         0
# Latitude                          0
# ID                                0
# Source                            0
# Location Source                   0
# Magnitude Source                  0
# Status                            0
# dtype: int64

# %%
# 📈 Magnitude distribution
plt.figure(figsize=(10, 6))
sns.histplot(df["Magnitude"], bins=30, kde=True)
plt.title("Distribution of Earthquake Magnitudes")
plt.xlabel("Magnitude")
plt.ylabel("Frequency")
plt.show()

# %%
# 📊 Number of earthquakes per year
plt.figure(figsize=(12, 6))
df['Year'].value_counts().sort_index().plot(kind='line')
plt.title("Number of Earthquakes Per Year")
plt.xlabel("Year")
plt.ylabel("Count")
plt.grid(True)
plt.show()

# %%
# 🌋 Depth vs. Magnitude
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Depth', y='Magnitude', alpha=0.5)
plt.title("Depth vs Magnitude")
plt.xlabel("Depth (km)")
plt.ylabel("Magnitude")
plt.show()

# %%
# 🗺️ Global earthquake map
fig = px.scatter_geo(df, lat='Latitude', lon='Longitude', color='Magnitude',
                     hover_name="ID", size="Magnitude",
                     projection="natural earth",
                     title="Global Earthquake Map")
fig.show()

# %% [markdown]
# ## 📊 Insights
#
# - Most earthquakes are between magnitude 5.0 and 6.0.
# - Frequency of recorded earthquakes increased over the decades.
# - Shallow earthquakes are more frequent than deep ones.
# - Earthquake hotspots are mostly located along tectonic boundaries like the Pacific Ring of Fire.
#
# ## 🚀 Next Steps
#
# - Apply clustering techniques (e.g., KMeans) to identify seismic zones.
# - Create a predictive model for magnitude based on depth and location.
# - Compare earthquake patterns across continents or tectonic plates.

# %% [markdown]
# ✅ Conclusion
# After analyzing the data, I found that most earthquakes are shallow and have magnitudes between 5.0 and 6.0. Earthquakes have become more frequently recorded over the years, which could be related to better monitoring systems. I also discovered that many earthquakes happen near tectonic boundaries, especially around the Pacific Ring of Fire.
#
# This was a great project to practice data cleaning, visualization, and storytelling through data. In the future, I’d love to expand this by trying clustering techniques or predicting earthquake strength based on depth and location.
#
# Thanks for visiting my notebook, and feel free to leave comments or feedback!
